# %% [markdown]
# <a href="https://colab.research.google.com/github/iesataulfoargentasor/sbd_2026_2027_new/blob/main/notebooks/practica_sonicwave.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🎧 Práctica: "SonicWave" — Matemática Discreta para un negocio real
#
# ## El caso
#
# **SonicWave** es una plataforma de música en streaming con miles de usuarios. El equipo de datos (¡tú!) tiene que responder preguntas de negocio al cierre del mes. La dirección quiere lanzar una campaña, y todas sus preguntas se responden con **las herramientas del cuaderno de teoría**:
#
# > conjuntos · relaciones · funciones · lógica · grafos · combinatoria · aritmética modular · estructuras de datos
#
# ## Cómo trabajar
#
# - Cada apartado tiene una **pregunta de negocio** en lenguaje natural y una **celda vacía** donde responder con código.
# - Escribe tu código debajo de cada comentario `# TU CÓDIGO AQUÍ` y ejecuta la celda.
# - Los datos son deliberadamente pequeños (para poder verificar "a mano"), pero las soluciones serían **idénticas con un millón de filas**.
# - Al final hay una **tabla de reflexión** para rellenar.
#
# **Puntuación sugerida:** 10 preguntas · 1 punto cada una · la 4 y la 7 dan medio punto extra por la explicación.

# %% [markdown]
# # 📦 Los datos de SonicWave
#
# La celda siguiente contiene **todo el dataset** de la práctica (datos de mayo). Son **tres tablas**:
#
# 1. **`oyentes_pop`** / **`oyentes_rock`** → conjuntos de usuarios que escucharon cada género (extraídos de los logs de reproducción).
# 2. **`sigue`** → relación *"sigue a"* entre usuarios (como en Twitter: ¡no tiene por qué ser mutua!).
# 3. **`usuarios`** → tabla de perfiles: edad, plan (gratis/premium) y nº de canciones escuchadas.
#
# Los datos son deliberadamente pequeños para que puedas verificar los resultados "a mano", pero las soluciones serían **idénticas con un millón de filas**.

# %%
# NO MODIFIQUES ESTA CELDA — solo ejecútala y lee la salida

# Tabla 1: qué género escuchó cada usuario en mayo
oyentes_pop  = {"Ana", "Juan", "Marta", "Sofía", "Luis"}
oyentes_rock = {"Juan", "Sofía", "Pedro", "Elena"}

# Tabla 2: relación "sigue a" (a, b) = 'a sigue a b'
sigue = {("Ana", "Juan"), ("Juan", "Ana"), ("Ana", "Sofía"),
         ("Marta", "Elena"), ("Elena", "Ana"), ("Pedro", "Ana")}

usuarios_todos = {"Ana", "Juan", "Marta", "Sofía", "Luis", "Pedro", "Elena"}

# Tabla 3: perfiles de usuario
usuarios = [
    {"nombre": "Ana",   "edad": 26, "plan": "gratis",  "canciones": 120},
    {"nombre": "Juan",  "edad": 31, "plan": "premium", "canciones": 340},
    {"nombre": "Marta", "edad": 24, "plan": "gratis",  "canciones": 45},
    {"nombre": "Sofía", "edad": 29, "plan": "premium", "canciones": 280},
    {"nombre": "Luis",  "edad": 35, "plan": "gratis",  "canciones": 60},
    {"nombre": "Pedro", "edad": 19, "plan": "gratis",  "canciones": 90},
    {"nombre": "Elena", "edad": 33, "plan": "premium", "canciones": 410},
]

print("Usuarios totales:", len(usuarios_todos))
print("Oyentes de pop: ", sorted(oyentes_pop))
print("Oyentes de rock:", sorted(oyentes_rock))
print("Relación 'sigue a':", sorted(sigue))

# %% [markdown]
# ## 🎯 BLOQUE 1 — Conjuntos
#
# ### Pregunta 1 · «¿A quién le mando la newsletter?»
#
# Marketing quiere enviar una newsletter sobre el nuevo festival de SonicWave, pero **solo una por usuario** (no molestar a nadie dos veces).
#
# > **¿A cuántos usuarios y a cuáles** debemos enviarla, si puede interesar tanto a los oyentes de pop como a los de rock?
#
# *Pista: ¿qué operación de conjuntos responde a "los que escucharon pop O rock, sin repetidos"?*
#
# ```python
# # TU CÓDIGO AQUÍ
# # newsletter = ...
# # print(...)
# ```
#
# ### Pregunta 2 · «El plan de fidelización»
#
# El equipo comercial quiere ofrecer una playlist premium a los usuarios que **ya escuchan los dos géneros** (pop Y rock): son los más musicales y probablemente pagarán premium.
#
# > **¿Quiénes son?** Y una segunda parte: ¿a qué oyentes de pop **todavía no** les interesaría esa oferta de rock?
#
# *Pista: dos operaciones distintas. La primera es "estar en las dos listas a la vez"; la segunda es "está en la de pop pero no en la de rock".*
#
# ```python
# # TU CÓDIGO AQUÍ
# ```
#
# ### Pregunta 3 · «¿Qué combinaciones puedo recomendar?**
#
# El sistema de recomendación quiere generar **todas las parejas posibles (usuario, género)** para compararlas después con lo que cada usuario ya escuchó y detectar huecos.
#
# > ¿Cuántas parejas hay? ¿Cuáles? ¿Qué **pareja concreta** representa *"Pedro todavía no ha escuchado pop → oportunidad"*?
#
# *Pista: producto cartesiano de `usuarios_todos` y `{"pop", "rock"}`. ¡Cuidado con el peligro de esta operación a gran escala!*
#
# ```python
# # TU CÓDIGO AQUÍ
# ```

# %%
# Pregunta 1 — ¿A quién le mando la newsletter?
# TU CÓDIGO AQUÍ

# Pregunta 2 — Plan de fidelización
# TU CÓDIGO AQUÍ

# Pregunta 3 — Parejas (usuario, género) para recomendaciones
# TU CÓDIGO AQUÍ

# %% [markdown]
# ## 🎯 BLOQUE 2 — Relaciones
#
# ### Pregunta 4 · «¿Es sana nuestra red social?»
#
# Producto quiere saber si SonicWave se comporta más como **Twitter** (seguir a, no mutuo) o como **Facebook** (amistad mutua). Hay dos preguntas concretas:
#
# > **(a)** ¿Es la relación `sigue` **simétrica**? *(¿cada "a sigue a b" tiene su vuelta "b sigue a a"?)*
# > **(b)** Si no lo es, **enumera los pares "rotos"** (los que no tienen vuelta) e identifica a los usuarios que **siguen sin ser correspondidos**.
# >
# > **Medio punto extra:** ¿es reflexiva? ¿Tiene sentido siquiera esperar eso en una red de "seguir a"?
#
# *Pista: reutiliza las funciones `es_simetrica(rel)` y `es_reflexiva(rel, conjunto)` del cuaderno de teoría. Para los pares rotos, un bucle o una comprensión con `if (b, a) not in sigue`.*
#
# ```python
# # TU CÓDIGO AQUÍ
# ```
#
# ### Pregunta 5 · «El índice de la red»
#
# Para que el buscador de "gente a la que sigues" sea instantáneo, construye la **lista de adyacencia** de la relación `sigue` (un diccionario: cada usuario → conjunto de usuarios a los que sigue).
#
# > Entrega el diccionario y responde: ¿a cuántas personas sigue Elena? ¿Quién es la persona **más seguida** de la plataforma?
#
# ```python
# # TU CÓDIGO AQUÍ
# ```

# %%
# Pregunta 4 — ¿Es simétrica la red? ¿Pares rotos?
# TU CÓDIGO AQUÍ

# Pregunta 5 — Lista de adyacencia de "sigue"
# TU CÓDIGO AQUÍ

# %% [markdown]
# ## 🎯 BLOQUE 3 — Funciones
#
# ### Pregunta 6 · «El indicador de engagement»
#
# Dirección no quiere ver "número de canciones" (un dato en bruto): quiere un **índice de compromiso** de 0 a 100, calculado como `100 - canciones // 5`. Cuantas más canciones, menor índice de "margen de crecimiento". *(Es un ejemplo didáctico de transformación; no busques lógica de negocio profunda.)*
#
# > **(a)** Define la función `f` que devuelve las canciones de un usuario y la transformación `g` (índice = `100 - canciones // 5`).
# > **(b)** Construye con una **comprensión de diccionario** el diccionario `engagement = {usuario: índice}` usando la **composición** `g(f(u))`.
# > **(c)** ¿Qué significa que el `engagement` de Marta (45 canciones) sea 91 y el de Elena (410) sea 18, **según la regla definida**? Una frase.
# > **(d)** ¿Qué pasa si pides `f("César")` y César no está registrado? ¿Cómo se llama ese concepto en matemáticas?
#
# ```python
# # TU CÓDIGO AQUÍ
# ```

# %%
# Pregunta 6 — Función f, transformación g y composición
# TU CÓDIGO AQUÍ

# (c) y (d) respóndelas también en un comentario o con print(...)

# %% [markdown]
# ## 🎯 BLOQUE 4 — Lógica
#
# ### Pregunta 7 · «¿Quién recibe la oferta premium?**
#
# Dirección define **cliente con potencial premium** así:
#
# > **(edad ≥ 25) Y (canciones > 100) Y (plan == "gratis")** — joven-ish, activo y aún sin pagar.
#
# > **(a)** Escribe el predicado como expresión booleana y obtén la lista de usuarios con potencial premium usando una **comprensión de lista** (traduce la regla tal cual a Python).
# > **(b)** Ahora define **"candidato a retención"**: *(plan == "gratis") Y NO (canciones > 50)* — gratis y casi inactivo, en riesgo de abandono. Usa `not`.
# > **(c)** Explica en una frase: ¿por qué la lista de (b) y la de (a) no comparten a nadie, aunque ambas parten de `plan == "gratis"`?
#
# *Medio punto extra por la explicación de (c).*
#
# ```python
# # TU CÓDIGO AQUÍ
# ```

# %%
# Pregunta 7 — Reglas lógicas de negocio
# TU CÓDIGO AQUÍ

# (c) respóndela en un comentario o con print(...)

# %% [markdown]
# ## 🎯 BLOQUE 5 — Grafos
#
# ### Pregunta 8 · «¿Quién es el influencer de SonicWave?**
#
# Vamos a ver la red de "sigue a" como lo que es: un **grafo dirigido**.
#
# > **(a)** Construye el grafo con `nx.DiGraph()` a partir de la relación `sigue` (cada par es una flecha).
# > **(b)** Calcula la **centralidad de grado** e identifícalo: ¿quién es la persona más influyente (más seguida)? *Pista: en un grafo dirigido, `G.in_degree(nodo)` cuenta los seguidores.*
# > **(c)** Dibuja la red y comprueba visualmente que (b) tiene sentido.
# > **(d)** Si ese influencer abandonara la plataforma, ¿cuántas flechas se perderían?
#
# *Nota: usa `nx.spring_layout(G, seed=42)` para que el dibujo sea reproducible.*
#
# ```python
# # TU CÓDIGO AQUÍ
# ```

# %%
# Pregunta 8 — Grafo dirigido de "sigue a"
# TU CÓDIGO AQUÍ

import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# ## 🎯 BLOQUE 6 — Combinatoria
#
# ### Pregunta 9 · «El festival de fin de curso»
#
# SonicWave va a montar un festival y quiere elegir **2 artistas** de entre los 5 que tienen confirmados: `["Dua Lipa", "Rosalía", "Bad Bunny", "Quevedo", "Karol G"]`.
#
# > **(a)** ¿Cuántas **parejas de artistas** (cartel, sin orden) puede formar? Calcula primero a mano con la fórmula y verifica con `itertools.combinations`.
# > **(b)** Si además hay que decidir **quién actúa primero y quién después** (orden importa), ¿cuántas opciones hay? Verifica con `permutations`.
# > **(c)** Reflexión: ¿por qué (b) es exactamente el doble de (a)?
#
# ```python
# # TU CÓDIGO AQUÍ
# ```

# %%
# Pregunta 9 — Combinatoria del festival
# TU CÓDIGO AQUÍ

from itertools import combinations, permutations

# %% [markdown]
# ## 🎯 BLOQUE 7 — Aritmética modular (teoría de grupos)
#
# ### Pregunta 10 · «Cupones secretos»
#
# Para no exponer los cupones en las URLs, SonicWave los "cifra" con un **cifrado César de desplazamiento k=5** sobre las 26 letras (¡exactamente el del cuaderno de teoría!).
#
# > **(a)** Define `cifrar(mensaje, k=5)` y `descifrar(mensaje, k=5)` usando aritmética modular (`% 26`).
# > **(b)** Cifra la palabra `"BONUS"` y muestra el resultado.
# > **(c)** Un cupón interceptado dice **`"MJQQT"`**. Descífralo (con k=5) y di qué palabra es.
# > **(d)** Explica en una frase por qué el `mod 26` es imprescindible: prueba a cifrar `"ZAPATO"` y mira qué le pasa a la **Z** (posición 25) cuando le sumas 5.
#
# ```python
# # TU CÓDIGO AQUÍ
# ```

# %%
# Pregunta 10 — Cifrado César de cupones
# TU CÓDIGO AQUÍ

# %% [markdown]
# ## 🎯 BLOQUE 8 — Estructuras de datos (integración final)
#
# ### Pregunta final · «El informe para dirección»
#
# Todo lo anterior, junto. Convierte la tabla `usuarios` en un **DataFrame de pandas** y responde **en menos de 6 líneas de código en total**:
#
# > **(a)** ¿Cuántas canciones se han escuchado en total por plan (gratis vs premium)?
# > **(b)** La edad media de los oyentes de pop *(pista: filtra el DataFrame con `.isin(oyentes_pop)`)*.
# > **(c)** ¿Qué estructura matemática de las vistas en clase es exactamente un DataFrame?
#
# *Este ejercicio vale 1 punto y evalúa la transferencia: de bucles y diccionarios a la herramienta profesional.*
#
# ```python
# # TU CÓDIGO AQUÍ
# import pandas as pd
# ```
#
# ---
#
# ## 🧠 Tabla de reflexión final (rellénala)
#
# | Pregunta de negocio | Operación/concepto usado | ¿Qué herramienta usarías con 10 millones de usuarios? |
# |---|---|---|
# | Newsletter a todos | | |
# | Usuarios de ambos géneros | | |
# | Recomendaciones (usuario, género) | | |
# | ¿Red simétrica? | | |
# | Influencer más seguido | | |
# | Parejas de artistas | | |
# | Cupón cifrado | | |
#
# > ✍️ **Entrega:** guarda este cuaderno como `practica_sonicwave_TU_NOMBRE.ipynb` y compártelo (o súbelo al repositorio del curso). Las respuestas en texto van en celdas de texto nuevas tras cada bloque.
#
# > 📚 **Material de apoyo:** todo lo necesario está en el cuaderno de teoría *Matemática Discreta aplicada a Big Data*. No hay nada que no se explique allí.

# %%
# Pregunta final — Informe con pandas
# TU CÓDIGO AQUÍ

import pandas as pd
