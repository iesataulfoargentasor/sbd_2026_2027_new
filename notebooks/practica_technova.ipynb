# %% [markdown]
# # 🛒 Práctica: "La tienda TechNova" — Matemática Discreta en un caso real
#
# **Módulo:** Sistemas de Big Data · **Duración estimada:** 2 horas
#
# ---
#
# ## 📖 El caso
#
# **TechNova** es una pequeña tienda online de electrónica que vende dos productos estrella: **auriculares** y **fundas de móvil**. Acaba de cerrar el mes y el equipo de marketing quiere tomar decisiones:
#
# * ¿A quién enviamos la próxima campaña?
# * ¿Quiénes son nuestros clientes VIP?
# * ¿Quién es el "influencer" del grupo de clientes en redes?
# * ¿Cuántas combinaciones de campaña podemos probar?
#
# El dueño te ha entregado los **datos del mes** (más abajo) y una lista de **preguntas de negocio**. Tu trabajo es responderlas usando las operaciones de matemática discreta que has aprendido en el cuaderno de teoría.
#
# ---
#
# ## 🗂️ Los datos
#
# ```python
# # Clientes que compraron cada producto este mes (de los tickets de compra)
# clientes_auriculares = {"Lucía", "Marcos", "Elena", "Pablo", "Nuria"}
# clientes_fundas      = {"Marcos", "Pablo", "Sergio", "Nuria"}
#
# # Datos de registro de cada cliente (edad y nº de compras este mes)
# perfil = {
#     "Lucía":  {"edad": 34, "compras": 7},
#     "Marcos": {"edad": 22, "compras": 9},
#     "Elena":  {"edad": 29, "compras": 3},
#     "Pablo":  {"edad": 41, "compras": 6},
#     "Nuria":  {"edad": 27, "compras": 4},
#     "Sergio": {"edad": 19, "compras": 2},
# }
#
# # Quién sigue a quién en la cuenta de Instagram de la tienda (¡seguir no es mutuo!)
# sigue_a = {
#     ("Lucía", "Marcos"), ("Marcos", "Lucía"), ("Lucía", "Elena"),
#     ("Elena", "Lucía"), ("Pablo", "Lucía"), ("Nuria", "Marcos"),
#     ("Sergio", "Elena"), ("Lucía", "Pablo"), ("Marcos", "Sergio"),
#     ("Nuria", "Lucía"),
# }
#
# # Gasto total de cada cliente este mes (en euros)
# gasto = {"Lucía": 145.0, "Marcos": 98.5, "Elena": 42.0, "Pablo": 210.0,
#          "Nuria": 76.5, "Sergio": 15.0}
# ```
#
# ---
#
# ## 📝 Cómo trabajar
#
# * Responde **cada pregunta en su celda de código** (las marcadas con `# TU CÓDIGO AQUÍ`).
# * Antes de programar, **escribe en la celda de texto previa** qué operación matemática vas a usar y por qué (esto forma parte de la evaluación).
# * Al final del cuaderno hay una **celda de autoevaluación**: si la ejecutas y todo está bien, verás `✅`.
# * Puedes consultar el cuaderno de teoría siempre que quieras: no hay trampas, solo práctica.
#
# ---

# %%
# Ejecuta esta celda para cargar los datos del caso (no hace falta modificar nada)

clientes_auriculares = {"Lucía", "Marcos", "Elena", "Pablo", "Nuria"}
clientes_fundas      = {"Marcos", "Pablo", "Sergio", "Nuria"}

perfil = {
    "Lucía":  {"edad": 34, "compras": 7},
    "Marcos": {"edad": 22, "compras": 9},
    "Elena":  {"edad": 29, "compras": 3},
    "Pablo":  {"edad": 41, "compras": 6},
    "Nuria":  {"edad": 27, "compras": 4},
    "Sergio": {"edad": 19, "compras": 2},
}

sigue_a = {
    ("Lucía", "Marcos"), ("Marcos", "Lucía"), ("Lucía", "Elena"),
    ("Elena", "Lucía"), ("Pablo", "Lucía"), ("Nuria", "Marcos"),
    ("Sergio", "Elena"), ("Lucía", "Pablo"), ("Marcos", "Sergio"),
    ("Nuria", "Lucía"),
}

gasto = {"Lucía": 145.0, "Marcos": 98.5, "Elena": 42.0, "Pablo": 210.0,
         "Nuria": 76.5, "Sergio": 15.0}

print("Datos cargados ✅  —", len(perfil), "clientes registrados")

# %% [markdown]
# # 🧩 Bloque 1 — Conjuntos: preparar la campaña
#
# El jefe de marketing de TechNova quiere lanzar una campaña para vender más **fundas de móvil**. Para decidir a quién escribirla, te hace estas preguntas:
#
# > **Pregunta 1.** ¿Cuántos clientes únicos tenemos en total? (es decir, ¿cuánta gente compró *algo* este mes?)
# >
# > **Pregunta 2.** ¿Qué clientes compraron **los dos productos**? (serán nuestros "clientes cruzados")
# >
# > **Pregunta 3.** ¿Qué clientes compraron **auriculares pero todavía no tienen funda**? → a ellos va dirigida la campaña de fundas.
# >
# > **Pregunta 4.** ¿Qué clientes compraron **solo uno de los dos productos** (cualquiera de ellos)?
#
# *Escribe en esta celda de texto qué operación usarás para cada pregunta y por qué (unión, intersección, diferencia, diferencia simétrica…).*

# %%
# Pregunta 1: clientes únicos (¿quién compró ALGO?)
# TU CÓDIGO AQUÍ

# Pregunta 2: clientes cruzados (compraron los dos productos)
# TU CÓDIGO AQUÍ

# Pregunta 3: objetivo de la campaña de fundas (auriculares SIN funda)
# TU CÓDIGO AQUÍ

# Pregunta 4: clientes de un solo producto
# TU CÓDIGO AQUÍ

# %% [markdown]
# # 🧩 Bloque 2 — Relaciones: la cuenta de Instagram
#
# TechNova quiere entender la red de su cuenta de Instagram. Los datos están en `sigue_a`: cada par `("Lucía", "Marcos")` significa que **Lucía sigue a Marcos**. Recuerda que *seguir no es mutuo* (como en Twitter).
#
# > **Pregunta 5.** ¿La relación "sigue a" es **simétrica**? Compruébalo programáticamente y, si no lo es, indica **qué flechas no tienen vuelta**.
# >
# > **Pregunta 6.** Construye la **lista de adyacencia** de la relación: un diccionario `persona → conjunto de personas a las que sigue`.
# >
# > **Pregunta 7.** Usando la lista de adyacencia (y SIN recorrer `sigue_a` de nuevo): ¿a cuántas personas sigue Lucía? ¿Quién es la persona **más seguida** (la que aparece en más listas de seguimiento)?
#
# *Escribe aquí qué propiedad de relaciones estás comprobando en la pregunta 5 y qué estructura de datos te da la respuesta rápida en la 7.*

# %%
# Pregunta 5: ¿es simétrica? ¿qué flechas no tienen vuelta?
# TU CÓDIGO AQUÍ

# Pregunta 6: lista de adyacencia (persona -> a quién sigue)
personas = set(perfil)  # todas las personas del caso
# TU CÓDIGO AQUÍ

# Pregunta 7: nº de seguidos de Lucía y persona MÁS SEGUIDA
# (pista para "más seguida": cuenta, para cada persona, en cuántas listas aparece)
# TU CÓDIGO AQUÍ

# %% [markdown]
# # 🧩 Bloque 3 — Funciones: puntuar a los clientes
#
# TechNova quiere crear una **puntuación de cliente** para ordenar el listado. La regla elegida es:
#
# $$\text{puntuación}(c) = 50 - 2 \cdot \text{edad}(c) + 10 \cdot \text{compras}(c)$$
#
# (jóvenes y compradores habituales puntúan más alto)
#
# > **Pregunta 8.** Define la función `f(c)` que, dado el nombre de un cliente, devuelve su edad (usa el diccionario `perfil`; debe devolver `None` si el cliente no existe).
# >
# > **Pregunta 9.** Define la función `g(edad, compras)` que aplica la fórmula de puntuación.
# >
# > **Pregunta 10.** Usando **composición** (como en el cuaderno de teoría: `g(f(...))`), construye el diccionario `puntuacion = {cliente: puntuación}` para todos los clientes. ¿Quién es el cliente con mayor puntuación?
#
# *Escribe aquí qué papel juega `f` (consulta) y qué papel juega `g` (transformación), y por qué decimos que `perfil` "es" una función matemática.*

# %%
# Pregunta 8: función f(cliente) -> edad (None si no existe)
def f(cliente):
    # TU CÓDIGO AQUÍ
    pass

# Pregunta 9: función g(edad, compras) -> puntuación
def g(edad, compras):
    # TU CÓDIGO AQUÍ
    pass

# Pregunta 10: composición -> diccionario puntuacion y cliente top
# TU CÓDIGO AQUÍ

# %% [markdown]
# # 🧩 Bloque 4 — Lógica: segmentar para la campaña
#
# Ahora el equipo quiere enviar un **cupón descuento** con esta regla de negocio:
#
# > *«Recibe cupón quien tenga **más de 25 años** **y** haya hecho **5 o más compras** este mes»*
#
# > **Pregunta 11.** Escribe el predicado `P` (edad > 25) y el predicado `Q` (compras ≥ 5), y usa `P and Q` para obtener la lista `con_cupon`. ¿Cuántos son?
# >
# > **Pregunta 12.** El jefe dice: *"es demasiado restrictivo; quiero llegar a más gente"*. Construye la lista `cupon_ampliado` con quienes cumplan **alguna** de las dos condiciones (P o Q).
# >
# > **Pregunta 13.** Legal ha pedido **excluir a los menores de 18** de cualquier campaña. Usa `not` para construir `sin_menores` a partir de `cupon_ampliado`.
# >
# > **Pregunta 14 (sin código).** Explica con la analogía de conjuntos: ¿qué operación de conjuntos es `P and Q`? ¿Y `P or Q`? ¿Y `not (menores)`?
#
# *Escribe aquí tu razonamiento de la pregunta 14 antes de programar.*

# %%
# Pregunta 11: P and Q -> lista con_cupon
# TU CÓDIGO AQUÍ

# Pregunta 12: P or Q -> lista cupon_ampliado
# TU CÓDIGO AQUÍ

# Pregunta 13: not (menor de 18) aplicado a cupon_ampliado -> sin_menores
# TU CÓDIGO AQUÍ

# %% [markdown]
# # 🧩 Bloque 5 — Grafos: ¿quién difunde mejor la campaña?
#
# El equipo quiere que la campaña se difuma por Instagram, así que decide regalaur un producto a la persona **mejor conectada** de la red de seguidores. La arista entre dos personas existirá cuando **al menos uno siga al otro**.
#
# > **Pregunta 15.** Construye un grafo **no dirigido** `G` con `networkx`: los nodos son las 6 personas y una arista `("A","B")` existe si `("A","B")` **o** `("B","A")` está en `sigue_a`.
# >
# > *(Pista: puedes recorrer `sigue_a` y hacer `G.add_edge(a, b)`; en un grafo no dirigido, la arista `(B,A)` y la `(A,B)` son la misma.)*
# >
# > **Pregunta 16.** Calcula la **centralidad de grado** y di quién es la persona mejor conectada. ¿Coincide con la persona "más seguida" del bloque 2? ¿Por qué sí o no?
# >
# > **Pregunta 17.** Dibuja el grafo con `nx.draw(...)` y comprueba visualmente tu respuesta.
#
# *Escribe aquí tu predicción ANTES de ejecutar: ¿quién crees que será el más central? ¿Por qué?*

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Pregunta 15: grafo no dirigido a partir de sigue_a
G = nx.Graph()
# TU CÓDIGO AQUÍ

# Pregunta 16: centralidad de grado -> persona mejor conectada
# TU CÓDIGO AQUÍ

# Pregunta 17: dibujo
pos = nx.spring_layout(G, seed=42)
# TU CÓDIGO AQUÍ (nx.draw + plt.show)

# %% [markdown]
# # 🧩 Bloque 6 — Combinatoria: diseñar el experimento
#
# Marketing quiere hacer una **prueba A/B**: elegir 2 clientes del grupo `con_cupon` (bloque 4) para entrevistarlos en profundidad, y además combinar **2 creatividades** (foto o vídeo) con **3 mensajes** ("novedad", "descuento", "últimas unidades").
#
# > **Pregunta 18.** ¿Cuántos **equipos de 2 entrevistados** se pueden formar con los clientes de `con_cupon`? Resuélvelo con `itertools.combinations` y comprueba el resultado con la fórmula $\binom{n}{2} = \frac{n!}{2!(n-2)!}$ usando `math.factorial`.
# >
# > **Pregunta 19.** ¿Cuántas **variantes de campaña** (creatividad + mensaje) se pueden montar? Resuélvelo con `itertools.product` y explica qué regla de conteo estás aplicando.
# >
# > **Pregunta 20 (para pensar).** Si en vez de entrevistar a 2 clientes de `con_cupon` hubiera que darles **dos cargos distintos** (entrevistador principal y ayudante), ¿sería combinación o permutación/variación? ¿Habría más o menos opciones?
#
# *Escribe aquí tu respuesta a la pregunta 20.*

# %%
from itertools import combinations, product
import math

# Pregunta 18: equipos de 2 entrevistados de con_cupon (+ comprobación con factorial)
# TU CÓDIGO AQUÍ

# Pregunta 19: variantes de campaña (creatividad x mensaje)
creatividades = ["foto", "vídeo"]
mensajes = ["novedad", "descuento", "últimas unidades"]
# TU CÓDIGO AQUÍ

# %% [markdown]
# # 🧩 Bloque 7 — Aritmética modular: el código promocional
#
# Para que el cupón no sea trivial de adivinar, TechNova genera un **código promocional** desplazando las letras de una palabra clave con un cifrado César de desplazamiento `k = 5`.
#
# > **Pregunta 21.** Define `cifrar(texto, k)` y `descifrar(texto, k)` usando aritmética modular (`% 26`), como en el cuaderno de teoría. La palabra clave es `"TECHNOVA"`.
# >
# > **Pregunta 22.** El sistema ha recibido el código cifrado `"XJHWJYT"` (desplazamiento `k = 5`). Descífralo: ¿qué palabra era?
# >
# > **Pregunta 23 (para pensar).** ¿Por qué necesitamos el `% 26`? ¿Qué pasaría al cifrar la `'Z'` sin él? Relaciónalo con la propiedad de **clausura** de la teoría de grupos.
#
# *Escribe aquí tu respuesta a la pregunta 23.*

# %%
letras = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"

# Pregunta 21: cifrar y descifrar (César con % 26)
def cifrar(texto, k):
    # TU CÓDIGO AQUÍ
    pass

def descifrar(texto, k):
    # TU CÓDIGO AQUÍ
    pass

# Prueba: cifra y descifra "TECHNOVA" y comprueba que recuperas lo original
# TU CÓDIGO AQUÍ

# Pregunta 22: descifra "XJHWJYT" con k=5
# TU CÓDIGO AQUÍ

# %% [markdown]
# # 🧩 Bloque 8 — Estructuras de datos: el informe final
#
# Para cerrar, debes presentar los resultados al jefe en formato profesional: **vector, tabla y agregaciones**.
#
# > **Pregunta 24.** Convierte el diccionario `gasto` en dos arrays de numpy: `nombres` y `gastos`. Calcula el **gasto medio** y el **gasto total** usando operaciones de numpy (sin bucles).
# >
# > **Pregunta 25.** Crea un DataFrame de pandas con columnas `cliente`, `edad`, `compras` y `gasto` (saca los datos de `perfil` y `gasto`). Añade una columna `puntuacion` con la puntuación del bloque 3.
# >
# > **Pregunta 26.** Con `groupby` no se puede (no hay categorías), pero sí puedes: usando el DataFrame, obtén **el gasto total de los clientes con cupón** (bloque 4) frente a los que no lo tienen. ¿Qué grupo deja más dinero?
#
# *Escribe aquí tu conclusión de negocio en 2-3 frases: ¿tiene sentido regalar el cupón a ese grupo?*

# %%
import numpy as np
import pandas as pd

# Pregunta 24: arrays de numpy + gasto medio y total sin bucles
# TU CÓDIGO AQUÍ

# Pregunta 25: DataFrame cliente/edad/compras/gasto + columna puntuacion
# TU CÓDIGO AQUÍ

# Pregunta 26: gasto total de con_cupon vs el resto
# (pista: df["cliente"].isin(con_cupon) crea una máscara booleana)
# TU CÓDIGO AQUÍ

# %%
# ✅ Autoevaluación — ejecuta esta celda cuando termines (no la modifiques)

def check(nombre, valor, esperado):
    ok = valor == esperado
    print(f"{'✅' if ok else '❌'} {nombre}: {valor!r}" + ("" if ok else f" (esperado {esperado!r})"))
    return ok

aciertos = 0
total = 0

try:
    total += 1; aciertos += check("B1 · clientes únicos (P1)", len(clientes_auriculares | clientes_fundas), 6)
except Exception as e: print("❌ B1 P1 sin resolver:", e)
try:
    total += 1; aciertos += check("B1 · clientes cruzados (P2)", sorted(clientes_auriculares & clientes_fundas), ["Marcos", "Nuria", "Pablo"])
except Exception as e: print("❌ B1 P2 sin resolver:", e)
try:
    total += 1; aciertos += check("B1 · objetivo campaña (P3)", sorted(clientes_auriculares - clientes_fundas), ["Elena", "Lucía"])
except Exception as e: print("❌ B1 P3 sin resolver:", e)
try:
    total += 1; aciertos += check("B2 · ¿simétrica? (P5)", all((b, a) in sigue_a for (a, b) in sigue_a), False)
except Exception as e: print("❌ B2 P5 sin resolver:", e)
try:
    total += 1; aciertos += check("B3 · cliente top (P10)", max(puntuacion, key=puntuacion.get), "Marcos")
except Exception as e: print("❌ B3 P10 sin resolver:", e)
try:
    total += 1; aciertos += check("B4 · con cupón (P11)", sorted(con_cupon), ["Lucía", "Pablo"])
except Exception as e: print("❌ B4 P11 sin resolver:", e)
try:
    total += 1; aciertos += check("B4 · cupón ampliado (P12)", sorted(cupon_ampliado), ["Elena", "Lucía", "Marcos", "Nuria", "Pablo"])
except Exception as e: print("❌ B4 P12 sin resolver:", e)
try:
    total += 1; aciertos += check("B5 · nº de aristas (P15)", G.number_of_edges(), 7)
except Exception as e: print("❌ B5 P15 sin resolver:", e)
try:
    total += 1; aciertos += check("B5 · más central (P16)", max(nx.degree_centrality(G), key=nx.degree_centrality(G).get), "Lucía")
except Exception as e: print("❌ B5 P16 sin resolver:", e)
try:
    total += 1; aciertos += check("B6 · variantes campaña (P19)", len(list(product(creatividades, mensajes))), 6)
except Exception as e: print("❌ B6 P19 sin resolver:", e)
try:
    total += 1; aciertos += check("B7 · descifrado (P22)", descifrar("XJHWJYT", 5), "SECRETO")
except Exception as e: print("❌ B7 P22 sin resolver:", e)

print(f"\n🏆 Resultado: {aciertos}/{total} comprobaciones automáticas superadas")
print("Recuerda: las preguntas 'para pensar' (14, 20, 23) y las celdas de texto se evalúan a mano.")

# %% [markdown]
# # 📤 Entrega
#
# 1. Completa todas las celdas de código y las celdas de texto de razonamiento.
# 2. Ejecuta **todas** las celdas en orden (`Entorno de ejecución → Ejecutar todo`).
# 3. Comprueba la autoevaluación final.
# 4. Descarga el cuaderno (`Archivo → Descargar → .ipynb`) y entrégalo en el plazo indicado.
#
# **Criterios de evaluación:**
# | Aspecto | Peso |
# |---|---|
# | Resultados correctos (autoevaluación) | 40% |
# | Elección correcta de la operación/estructura en cada bloque | 30% |
# | Razonamiento en las celdas de texto (preguntas 14, 20, 23 y conclusiones) | 20% |
# | Limpieza del código y comentarios | 10% |
#
# > 💡 **Pista final:** cada bloque usa EXACTAMENTE las operaciones del cuaderno de teoría, con los mismos nombres de conceptos. Si te atascas, busca el bloque equivalente allí.
